# %% [markdown]
# # My Lakehouse Scratchpad
# Notebook created in Databricks Local Studio.
# Connected to in-process DuckDB Lakehouse (`warehouse`).

# %%
# Query Lakehouse tables directly via DuckDB
import duckrun
conn = duckrun.connect('/workspace/warehouse')
display(conn.sql('SHOW TABLES;').df())
